# %%
post_data = {
    'title': 'Sample Post Title',
    'text': 'This is the sample text for the post.',
    'image': 'path/to/image.jpg'  # Replace with the actual path to your image
}

print(post_data)
# Out:
# {'title': 'Sample Post Title', 'text': 'This is the sample text for the post.', 'image': 'path/to/image.jpg'}

# %%
import pandas as pd

# Define the path to the dataset
dataset_path = '/Users/macbookair/Documents/Project/fItneSS_us/recommendation/datasets/MIND/MINDlarge_dev/news.tsv'

# Load the dataset
dataset = pd.read_csv(dataset_path, sep='\t', header=None)
dataset.columns = ['news_id', 'category', 'subcategory', 'title', 'abstract', 'url', 'title_entities', 'abstract_entities']
dataset.head()
# Out:
#   news_id   category      subcategory  \
# 0  N88753  lifestyle  lifestyleroyals
# 1  N23144     health       weightloss
# 2  N86255     health          medical
# 3  N93187       news        newsworld
# 4  N75236     health           voices
#
#                                                title  \
# 0  The Brands Queen Elizabeth, Prince Charles, an...
# 1                      50 Worst Habits For Belly Fat
# 2  Dispose of unwanted prescription drugs during ...
# 3  The Cost of Trump's Aid Freeze in the Trenches...
# 4  I Was An NBA Wife. Here's How It Affected My M...
#
#                                             abstract  \
# 0  Shop the notebooks, jackets, and more that the...
# 1  These seemingly harmless habits are holding yo...
# 2                                                NaN
# 3  Lt. Ivan Molchanets peeked over a parapet of s...
# 4  I felt like I was a fraud, and being an NBA wi...
#
#                                              url  \
# ...

# %%
dataset['img_path'] = '/Users/macbookair/Documents/Project/fItneSS_us/recommendation/datasets/celebA_50k/' + str(dataset.index[0]+1).zfill(6) + '.jpg'
dataset.head()
# Out:
#   news_id   category      subcategory  \
# 0  N88753  lifestyle  lifestyleroyals
# 1  N23144     health       weightloss
# 2  N86255     health          medical
# 3  N93187       news        newsworld
# 4  N75236     health           voices
#
#                                                title  \
# 0  The Brands Queen Elizabeth, Prince Charles, an...
# 1                      50 Worst Habits For Belly Fat
# 2  Dispose of unwanted prescription drugs during ...
# 3  The Cost of Trump's Aid Freeze in the Trenches...
# 4  I Was An NBA Wife. Here's How It Affected My M...
#
#                                             abstract  \
# 0  Shop the notebooks, jackets, and more that the...
# 1  These seemingly harmless habits are holding yo...
# 2                                                NaN
# 3  Lt. Ivan Molchanets peeked over a parapet of s...
# 4  I felt like I was a fraud, and being an NBA wi...
#
#                                              url  \
# ...

# %%
print(dataset['img_path'][0])
# Out:
# /Users/macbookair/Documents/Project/fItneSS_us/recommendation/datasets/celebA_50k/000001.jpg

# %%
#exporting the dataset
dataset.to_csv('/Users/macbookair/Documents/Project/fItneSS_us/recommendation/datasets/news_with_img_path.csv', sep='\t', index=False, header=False)

# %%
import pandas as pd

# Define the path to the dataset
dataset_path = '/Users/macbookair/Documents/Project/fItneSS_us/recommendation/datasets/news_with_img_path.csv'

# Load the dataset
dataset = pd.read_csv(dataset_path, sep='\t', header=None)
dataset.columns = ['news_id', 'category', 'subcategory', 'title', 'abstract', 'url', 'title_entities', 'abstract_entities', 'img_path']
dataset.head()
# Out:
#   news_id   category      subcategory  \
# 0  N88753  lifestyle  lifestyleroyals
# 1  N23144     health       weightloss
# 2  N86255     health          medical
# 3  N93187       news        newsworld
# 4  N75236     health           voices
#
#                                                title  \
# 0  The Brands Queen Elizabeth, Prince Charles, an...
# 1                      50 Worst Habits For Belly Fat
# 2  Dispose of unwanted prescription drugs during ...
# 3  The Cost of Trump's Aid Freeze in the Trenches...
# 4  I Was An NBA Wife. Here's How It Affected My M...
#
#                                             abstract  \
# 0  Shop the notebooks, jackets, and more that the...
# 1  These seemingly harmless habits are holding yo...
# 2                                                NaN
# 3  Lt. Ivan Molchanets peeked over a parapet of s...
# 4  I felt like I was a fraud, and being an NBA wi...
#
#                                              url  \
# ...

# %%
dataset.loc[0]['img_path'],dataset.loc[0]['title'],dataset.loc[0]['abstract']
# Out:
# ('/Users/macbookair/Documents/Project/fItneSS_us/recommendation/datasets/celebA_50k/000001.jpg',
#  'The Brands Queen Elizabeth, Prince Charles, and Prince Philip Swear By',
#  "Shop the notebooks, jackets, and more that the royals can't live without.")

# %%
from postside import post_embeddings
from resnet import get_image_embeddings
get_image_embeddings('/Users/macbookair/Documents/Project/fItneSS_us/recommendation/datasets/celebA_50k/000001.jpg')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# tensor([[0.2286, 0.0000, 0.0024,  ..., 0.0000, 0.0000, 0.0000]])

# %%
get_image_embeddings(dataset.loc[0]['img_path'])
# Out:
# tensor([[0.2286, 0.0000, 0.0024,  ..., 0.0000, 0.0000, 0.0000]])

# %%
post_embeddings(dataset.loc[0]['img_path'],dataset.loc[0]['title'],dataset.loc[0]['abstract'])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tensor([[ 0.2286,  0.0000,  0.0024,  ..., -0.1980,  0.2810,  0.1527]])

# %%
from postside import tensor_to_bytes

# %%
tensor_to_bytes(post_embeddings(dataset.loc[0]['img_path'],dataset.loc[0]['title'],dataset.loc[0]['abstract']))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# ...

# %%
import pandas as pd
import numpy as np
import torch
import tensorflow as tf

print(pd.__version__)
print(tf.__version__)
print(torch.__version__)
# Out:
# 2.2.2
# 2.17.0
# 2.4.0
